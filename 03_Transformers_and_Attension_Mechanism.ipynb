# %% [markdown]
# ## Transformers and Attention Mechanism
#
# **Instructor : Jason Lin and Brian Cruz**
#
# ![image.png](attachment:1e357890-92f2-4c9c-b450-29a3ca2b0833.png)
#
# ![image.png](attachment:12f4c237-be10-471b-948a-f97768886ee0.png)
#
# <p align="center">
#   <img src="attachment:0a0924b6-1d74-4cba-8307-3e4d1f238620.png" width="400" />
#   <img src="attachment:cfe71d28-4696-46dc-8562-a05eb8930742.png" width="400" />
#   <img src="attachment:4c2e401c-7338-44b2-9059-fbdfdbfa5cea.png" width="400" />
# </p>
#
# <p align="center">
#   <img src="attachment:e6eedb60-f0ad-4790-8f56-101856a09f88.png" width="400" />
#   <img src="attachment:5029da20-411a-4bb6-a05c-311ec642a67e.png" width="400" />
#   <img src="attachment:b9c4e232-1d7f-4be3-9f3f-bc675683a0b2.png" width="400" />
# </p>
#
# <p align="center">
#   <img src="attachment:195f76d1-1d67-48a1-b5dc-568c00fd9e1f.png" width="400" />
#   <img src="attachment:69dacc64-da49-4130-9033-04ffed8882e4.png" width="400" />
#   <img src="attachment:fa2cae04-7f44-4aa0-ab26-b2ba5460c84f.png" width="400" />
#   <img src="attachment:2deb4ef2-5987-4590-9615-a34887dbede5.png" width="400" />
# </p>
#
#
#
# For self-attention, the Q, K, and V matrices are actually identical. For self-attention, they are obtained from token embeddings, which are the output of the previous neural network layer.

# %% [markdown]
# <p align="center">
#   <img src="attachment:809e833b-6ff0-4de5-9387-5fe801737157.png" width="330" />
#   <img src="attachment:de69a993-c8de-40fe-9019-869bd0411223.png" width="330" />
#   <img src="attachment:cdf760ac-bdb8-469a-b781-a1e66cc8f294.png" width="330" />
# </p>
#
# <p align="center">
#   <img src="attachment:16d17346-d12c-4c24-85dd-4f30edd3b740.png" width="330" />
#   <img src="attachment:1310749c-7697-4e2d-b1d3-d936f8bcae49.png" width="330" />
#   <img src="attachment:7e0d00f6-b6ca-43ab-9590-5d14c6225859.png" width="330" />
# </p>
#
# <p align="center">
#   <img src="attachment:195f76d1-1d67-48a1-b5dc-568c00fd9e1f.png" width="330" />
#   <img src="attachment:69dacc64-da49-4130-9033-04ffed8882e4.png" width="330" />
#   <img src="attachment:69dacc64-da49-4130-9033-04ffed8882e4.png" width="330" />
# </p>
