# %% [markdown]
# ## SciML
#
# Branch of ML and its a combination of ML and science
#
# * Traditional ML is like a black box. it is not interpretable
# * Using SciML, we can combine the power of neural networks with the interpretability
# *  Dr Chris Rackauskas sayins SciML is a model based data efficient ML
# * It uses the data with domain knowledge
# * A neural network is a universal function approximator : if we increase the number of neurons, it will approximate any function, it will mix NN with ODE/PDE
#
# ![image.png](attachment:1745e7bf-ef9c-43df-bd24-464a47de9dd3.png)
# ![image.png](attachment:123fb2fa-e6de-4473-bb67-09e1891aa5d7.png)

# %% [markdown]
# ![image.png](attachment:6c5559ad-13bd-46e6-b111-058a9c4a57e3.png)
# ![image.png](attachment:9673c973-3948-48e9-bea8-07d8a5d38963.png)
# ![image.png](attachment:9581a545-c365-424c-a6ca-c41495cfe870.png)
#
# * UDE In Simple terms: ODE/PDE + Neural Networks
#
# ![image.png](attachment:50f3f72c-95b0-4650-bff4-6b4a8d6fb2ae.png)

# %% [markdown]
# #### Gravitational Waves :
#
# * Our Project : Detect the wave form throguh time
# * Our aim: Recover the diff. equations.
# * Combine
#
#   ![Screenshot 2024-07-28 at 9.23.33 AM.png](attachment:94f875af-f0a0-4d89-a621-455a09db8d64.png)
#   ![image.png](attachment:1be93e3f-d675-4ae7-aa5f-05b8791ea4b0.png)

# %% [markdown]
# * ODE
# * PDE
# * UDE Universal Differential Equations
